# %%
import numpy as np
import cv2
import pandas as pd 
import matplotlib.pyplot as plt
import os 
import pickle  
# %matplotlib inline

# %%
flower_types = os.listdir(r"C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers")
print(flower_types)
print('Types of flowers found :', len(flower_types))
# Out:
# ['Lilly', 'Lotus', 'Orchid', 'Sunflower', 'Tulip']
# Types of flowers found : 5

# %%
flowers = []

for item in flower_types:
    all_flowers = os.listdir(r"C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers" + '/' +item)
for flower in all_flowers:
    flowers.append((item, str(r"C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers" + '/' +item) + '/' +flower))
    print(flowers[:1])
# Out:
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# [('Tulip', 'C:\\Users\\MMM\\Downloads\\deep learning - Copy\\3. mlp  five types of flowers/Tulip/009b4d16a9.jpg')]
# ...

# %%
flower_df = pd.DataFrame(data=flowers,columns=['flower type', 'image'])
print(flower_df.head())
print(flower_df.tail())
# Out:
#   flower type                                              image
# 0       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 1       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 2       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 3       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 4       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
#     flower type                                              image
# 995       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 996       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 997       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 998       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....
# 999       Tulip  C:\Users\MMM\Downloads\deep learning - Copy\3....

# %%
print('hshjh',len(flower_df))
# Out:
# hshjh 1000

# %%
directory = r"C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers"
categories = ['Lilly','Lotus','Orchid','Sunflower','Tulip']

# %%
for category in categories:
    folder = os.path.join(directory,category)
    for img in os.listdir(folder):
        img_path = os.path.join(folder,img)
        img_arr = cv2.imread(img_path)
        plt.imshow(img_arr)
        print(img_path)
        break
# Out:
# C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers\Lilly\00048a5c76.jpg
# C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers\Lotus\005fb079bf.jpg
# C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers\Orchid\002c100a56.jpg
# C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers\Sunflower\004e98f65a.jpg
# C:\Users\MMM\Downloads\deep learning - Copy\3. mlp  five types of flowers\Tulip\009b4d16a9.jpg
